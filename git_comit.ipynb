# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Git for tide 
% cd drive/MyDrive/projects/oceanography/tide

# %%
! git init

# %%
! git status

# %%
! git add .

# %%
! git status

# %%
# !git config --global user.email "firesinger@pukyong.ac.kr"
# !git config --global user.name "firesinger"

# %%
! git commit -m "gdrive to github"

# %%
username = "firesinger"
git_token = "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"
repository = "oceanography"

# %%
! git remote add origin https://{git_token}@github.com/{username}/{repository}.git

# %%
! git remote -v

# %%
! git push -u origin master
